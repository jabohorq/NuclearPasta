# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('rho01Sam1_db.csv')
df1
# Out:
#         xp0       yp0       zp0  ipp0  inp0       xp1       yp1       zp1  \
# 0  0.177253  0.020937  0.005375     1     0  0.215480  0.022285  0.007565
# 1  0.415156  0.056575  0.060082     1     0  0.399265  0.017177  0.078137
# 2  0.003533  0.000746  0.093678     1     0  0.021808  0.023451  0.142425
# 3  0.004735  0.019365  0.114002     1     0  0.030720  0.004933  0.087439
# 4  0.084641  0.055302  0.040997     1     0  0.024898  0.001129  0.057707
# 5  0.124642  0.023425  0.070021     1     0  0.124541  0.026595  0.116757
# 6  0.068764  0.027286  0.022586     1     0  0.070713  0.007227  0.085382
# 7  0.118471  0.017885  0.042216     1     0  0.082085  0.009223  0.043665
# 8  0.096616  0.036204  0.111080     1     0  0.138424  0.015803  0.079837
# 9  0.235077  0.001959  0.036641     1     0  0.193602  0.022326  0.079334
#
#    ipp1  inp1  ...    xn2915    yn2915    zn2915  ipn2915  inn2915    xn2916  \
# ...

# %%
df1.isnull().sum()
# Out:
# xp0        0
# yp0        0
# zp0        0
# ipp0       0
# inp0       0
#           ..
# xn2916     0
# yn2916     0
# zn2916     0
# ipn2916    0
# inn2916    0
# Length: 24565, dtype: int64

# %%
sns.histplot(df1.zn2916, bins=40)
# Out:
# <AxesSubplot:xlabel='zn2916', ylabel='Count'>
